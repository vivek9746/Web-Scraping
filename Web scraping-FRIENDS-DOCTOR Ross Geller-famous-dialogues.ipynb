# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('http://www.glamourmagazine.co.uk/gallery/ross-geller-friends-best-quotes')

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
results = soup.find_all('p', attrs={'class':'bb-p'})

# %%
result=results[3:]

# %%
for i in result:
    first=i
    
    raw_names=first.find_all('strong')
    filt_names=[]
    for i in raw_names:
        filt=i.text[:-1]
        filt_names.append(filt)

    rawspt=[]
    a=first.contents
    for i in range(len(a)):
        if isinstance(a[i], str):
            rawspt.append(a[i])
    k=[]

    for i in range(len(rawspt)):
        if('[' and ']' in list(rawspt[i])):
            new=[]
            new.append(a[i])
            rawspt[i]=rawspt[i]+rawspt[i+1]
            k.append(i+1)
    for l in k:
        del rawspt[l]

    del k[:]
    
    for x,y in zip(filt_names,rawspt):
        print(str(x)+" : "+y)
    print('\n\n')
# Out:
# Ross :  Yeah, I need uh... I'm just-I don't know-I don't understand, umm, how this happened? We-we used a condom.
# Rachel :  I know. I know, but y'know condoms only work like 97% of the time.
# Ross :  What? What? What? Well they should put that on the box!
# Rachel :  They do!
# Ross :  No they don't!
# Ross : [Runs to the bedroom and returns the condoms] Well they should put it in huge black letters!
# Rachel :  Okay Ross come on let's just forget about the condoms.
# Ross :  Oh well I may as well have!
#
#
#
# Ross :  My marriage, I think my marriage is kind of over.
# Phoebe :  Why?
# Ross :  Because my wife's a lesbian... And I'm not one.
#
#
#
# Will :  [about how he hates Rachel] It wasn't just me. We had a club.  You had a club?
# Rachel :  That's right. The I Hate Rachel Green Club.
# Will :  O my God! So what? You all just join together to hate me? Who else was in this club?
# Rachel :  Me and Ross.
# Will :  No need to point. She knows who Ross is.
#
#
#
# ...
